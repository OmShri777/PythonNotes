# %% [markdown]
# ### Python Syntax

# %% [markdown]
# ##### Execute Python Syntax
# - Python syntax can be executed by writing directly in the Command line.
# -  The set of rules that defines how a Python program will be written and interpreted (by both the runtime system and by human readers).

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# - Or by creating a python file on the server, using the .py file extension, and running it in the Command Line:

# %% [markdown]
# C:\Users\Your Name>python myfile.py

# %% [markdown]
# #### Python Indentation
# - Indentation refers to the spaces at the beginning of a code line.
#
# - Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.
#
# - Python uses indentation to indicate a block of code.

# %%
# Example
if 5 > 2:
    print("Five is greater than two")

# %% [markdown]
# - Python will give you an error if you skip the indentation

# %%
# Example
if 5 > 2:
print("Five is greater than two")
# Out:
#   Cell In[1], line 3
#     print("Five is greater than two")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %% [markdown]
# - The number of spaces is up to you as a programmer, the most common use is four,but it has to be at least one.

# %%
# Example
if 5 > 2:
    print("Five is greater than two")
if 5 > 2:
        print("Five is greater than two")
# Out:
# Five is greater than two
# Five is greater than two

# %% [markdown]
# - You have to use the same number of spaces in the block of code, otherwise Python will give you an error

# %%
if 5 > 2:
    print("Five is greater than two")
        print("Five is greater than two")
# Out:
#   Cell In[5], line 3
#     print("Five is greater than two")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# #### Python Variables
# - In Python, variables are created when you assign a value to it:

# %%
# Example
# Variable in Python:
x = 5
y = "Hello, World!"

# %%
print(x)
# Out:
# 5

# %%
print(y)
# Out:
# Hello, World!

# %% [markdown]
# Python has no command for declaring a variable.

# %% [markdown]
# #### Comments
# - Python has commenting capability foe the purpose of in code documentation.
# - Comments start with a # and Python will render the rest of the line as a comment:

# %%
# Example

# This is a comment
print("Hello, World!") # This is a print function
# Out:
# Hello, World!

# %% [markdown]
# #### Python Statements

# %% [markdown]
# ### Statements
# - A computer program is a list of "instructions" to be "executed" by a computer.
#
# - In a programming language, these programming instructions are called statements.
#
# - The following statement prints the text "Python is fun!" to the screen:

# %%
# Example
print("Python is a fun!")
# Out:
# Python is a fun!

# %% [markdown]
# In Python, a statement usually ends when the line ends. You do not need to use a semicolon (;) like in many other programming languages (for example, Java or C)

# %% [markdown]
# ##### Many Statements
# - Most Python programs contain many statements.
#
# - The statements are executed one by one, in the same order as they are written:

# %%
print("Hello, World!")
print("Have a good day!")
print("Learning Python is fun!")
# Out:
# Hello, World!
# Have a good day!
# Learning Python is fun!

# %% [markdown]
# Example explained
# From the example above, we have three statements:
#
#    print("Hello World!")
#    print("Have a good day.")
#    print("Learning Python is fun!")
#
# - The first statement is executed first (print "Hello World!").
# - Then the second statement is executed (print "Have a good day.").
# - And at last, the third statement is executed (print "Learning Python is fun!").

# %% [markdown]
# #### Semicolons (Optional,Rarely Used)
#
# - Semicolons are optional in Python. You can write multiple statements on one line by separating them with ; but this is rarely used because it makes it hard to read:

# %%
# Example
print("Hello"); print("How are you?"); print("Bye bye!")
# Out:
# Hello
# How are you?
# Bye bye!

# %% [markdown]
# However, if you put two statements on the same line without a separator (newline or ;), Python will give an error:

# %%
print("Python is fun!") print("Really!")
# Out:
#   Cell In[14], line 1
#     print("Python is fun!") print("Really!")
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# Best Practice: Put each statement on its own line so your code is easy to understand.
